# %%
import pandas as pd


df = pd.read_json("final_json.json")
df.head()
# Out:
#      molecule_name protein_target_name binding_metric value  unit  \
# 0            PCSK9                None             Kd    17    Kd
# 1            PCSK9                None             Kd    65    Kd
# 2              15u                None           None  None  None
# 3              15w                None           None  None  None
# 4  thienopyridines                NFKB           IC50  None  None
#
#    is_logarithmic     patent_number  protein_uniprot_id protein_seq_id
# 0             0.0     EP-2296694-A2                 NaN            NaN
# 1             0.0     EP-2296694-A2                 NaN            NaN
# 2             NaN  WO-2020237014-A1                 NaN           None
# 3             NaN  WO-2020237014-A1                 NaN           None
# 4             NaN  WO-2020237014-A1                 NaN           None

# %% [markdown]
# ### Filter

# %%
required_columns = [
    "molecule_name",
    "protein_target_name",
    "binding_metric",
    "value",
    "unit",
    "patent_number"
]

# Remove rows with any null in these columns
df_clean = df.dropna(subset=required_columns)

print(f"Filtered rows: {len(df) - len(df_clean)} removed, {len(df_clean)} remain.")
# Out:
# Filtered rows: 11546 removed, 3619 remain.

# %% [markdown]
# ### Find strange units

# %%
def normalize_unit(unit):
    # Lowercase, remove spaces, replace Greek μ with 'u'
    return str(unit).lower().replace(' ', '').replace('μ', 'u').replace('µ', 'u')

# Make a normalized unit column for comparison
df['unit_norm'] = df['unit'].apply(normalize_unit)

# Get unique units that are not 'nm'
not_nm_units = df.loc[df['unit_norm'] != 'nm', 'unit'].dropna().unique()

print("Unique unit values (not nM):")
for u in not_nm_units:
    print(f"- {u}")
# Out:
# Unique unit values (not nM):
# - Kd
# - mg/kg
# - %
# - μM
# - uM
# - M
# - pM
# - mg/animal
# - M⁻¹min⁻¹
# - μg/ml
# - µM
# - mol/L
# - μm
# - μΜ
# - μM/nM
# - M-1
# - mM
# - fold
# - mg/kg p.o.
# - times
# - nM.h
# - micromolar
# - sec−1
# - M−1 sec−1
# - pg/mL
# - KD
# - μg/mouse/day
# - μg
# - pM-nM
# - cpm/pmol
# - Kd app. MW
# - μl/ml
# - millimolar
# - μCi/μg protein
# - M^-1
# - pmol/g
# - ng/mL
# - μ mol/L
# - °
# - μg/kg/day
# - ng/ml
# - kD
# - μmol/L
# - none
# - nmol/L
# - nmol/500,000 cells/24 h
# - μg/kg
# - % ID/cm^3
# - min
# - L
# - micromolar or sub-micromolar
# - s-1
# - Pa
# - s
# - kPa
# - mmol/L
# - ug/ml
# - s−1
# - nM/pM
# - M−1s−1
# - pg/head
# - cells/mL
# - cells/50 pL/mouse
# - hours
# - kcal/mol
# - picomolar
# - μg/mL
# - °C
# - μg PL/mL
# - μg /PL/mL
# - /second
# - M^-1/second
# - mL
# - g/mL
# - mCi/μmol
# - μg / ml
# - Molar concentration
# - s^-1
# - x
# - ug/mL
# - mg/ml
# - μg protein/mL
# - pmol/mg/min
# - Ci/mmol
# - μg mL^-1
# - microL
# - days
# - cell/ml
# - μMol
# - TIU/mg protein
# - 1/Ms
# - 1/s
# - 1/RUs
# - ml/min/kg
# - mg/dL of FPG per h
# - h−1
# - pg/μl
# - nM, μM
# - mg/mL
# - μg per gram of gel
# - μg per tooth
# - m
# - L/mole
# - mg/kg/day
# - ng
# - sub-nanomolar
# - mg/kg body weight
# - fM
# - molar units or g/L
# - mg/L
# - pH
# - mu. mol/L
# - M−1 s−1
# - M^−1
# - M−1 cm−1
# - RU
# - mu M
# - 0.7
# - 1.4
# - 70.8
# - cells/well
# - 1/M
# - nM/milligrams
# - millimole/milligrams
# - resonance units
# - m^-1
# - nanometer
# - micro-rub
# - micro-ATP
# - Mu.M
# - nmol 5α-DHT formed/15 min
# - pmol 5α-DHT formed/mg protein/15 min
# - µg/ml
# - μCi
# - M−1
# - moles
# - mV
# - pA/pF
# - mM−1s−1
# - umol/kg
# - mM / L
# - folds
# - pM/nM
# - µg
# - ug
# - gram
# - hr
# - hr*ng/mL
# - Ci/mmole
# - Mu.L
# - μmol/l
# - lU/ml
# - μg/well
# - mMol/kg
# - Unit/mg
# - Kda
# - KDa
# - U/mL
# - U/mouse
# - mg/kg per day
# - 3
# - mmol/l
# - nmol/l
# - M^-1s^-1
# - L"1"
# - BU/ml
# - InM
# - nanomolar
# - nmolar
# - kd
# - % ID/g*kg
# - % ID/g
# - nmol/mg tissue/min
# - months
# - minutes
# - mΐ
# - mu.M
# - μ M
# - percent
# - mole/liter
# - U/ml
# - >10μM
# - micromole
# - nmoles
# - μL
# - pg/ml
# - pg/dose
# - x 10^-9 (M)
# - μ M and nM
# - fold increase
# - Mu.g/mL
# - U/mg*10^−3
# - μg/100 μl PBS
# - pg/10^6 cells
# - 0.07
# - 1.8
# - 2.5
# - 0.49
# - 0.5
# - 0.41
# - 0.76
# - μηηοΙ Gd/kg
# - μηηοΙ Gd/L
# - μηιοΙ Gd/L
# - μηηοΙ Gadolinium/L
# - μηηοΙ Gd/ kg
# - μηηοΙ molecule/kg
# - nanomolar range
# - Molar
# - µg/mL
# - M^1
# - M^1s^1
# - s^1
# - M^-1S^1
# - M^1S^1
# - nM to μM
# - ppm
# - cpm/ng
# - M-l
# - g
# - mN
# - nM or less
# - microM
# - molecular weight
# - muM
# - kcal-mol^-1-heavy atom^-1
# - μl
# - ml/min
# - ℃
# - ng/mL, μg/mL
# - units/ml
# - μCi/μg
# - μ L
# - μg * hr/mL
# - times of molar excess
# - nM to uM
# - μCi/μM
# - .mu.M
# - MU
# - mg
# - mol/l
# - mol/1
# - dilution
# - O.D. /min
# - nM-uM
# - Mg/ml
# - s<sup>−1</sup>
# - sec^−1
# - nanograms per milliliter
# - nanograms/milliliter
# - seconds
# - μMs
# - mM/nM
# - mg/m^2
# - μmol/kg
# - 10^5 mol/L^-1s^-1
# - 10^-4 s^-1
# - 10^-9 mol/L
# - ng/mL or nM
# - mg/l
# - NIH units
# - cpm
# - kcal

# %% [markdown]
# ### Find strange binding_metrics

# %%
def normalize_metric(metric):
    # Lowercase, remove spaces
    return str(metric).strip().lower().replace(' ', '')

allowed_metrics = {'ki', 'kd', 'ic50', 'ec50'}

# Add a normalized column for comparison
df['binding_metric_norm'] = df['binding_metric'].apply(normalize_metric)

# Find unique "strange" metrics
strange_metrics = (
    df.loc[~df['binding_metric_norm'].isin(allowed_metrics), 'binding_metric']
    .dropna()
    .unique()
)

print("Strange binding_metric values (not Ki, Kd, IC50, EC50):")
for metric in strange_metrics:
    print(f"- {metric}")
# Out:
# Strange binding_metric values (not Ki, Kd, IC50, EC50):
# - POC
# - Kds
# - K_i
# - K_i, EC50
# - ED50
# - LD50
# - kₑ
# - MIC
# - pK
# - IC
# - MIC50
# - IC-50
# - MICso
# - ICeo
# - K_D
# - association constant
# - K
# - MED
# - EC50s
# - Koff
# - Kon
# - penetration
# - potency
# - growth reduction
# - measurable response
# - specific activity
# - pKw
# - binding constant
# - molecular weight
# - minimum inhibitory concentration
# - concentration
# - inhibition
# - pIC50
# - incorporation
# - IC30
# - pKa
# - Ki(app)
# - affinity
# - apparent association constant (aKa)
# - EC50 ratio
# - Equilibrium dissociation constant
# - half-time
# - steady distribution volume
# - koff
# - EC50 or IC50
# - pEC50
# - G′max
# - Relaxation time
# - Swelling ratio
# - G′ max
# - relaxation time
# - G″max
# - CC50
# - dissociation constant
# - Kj
# - killing EC50
# - ki*
# - K<sub>i </sub>
# - TI
# - pKi
# - ND50
# - LLOQ
# - Cmax
# - AUC
# - T1/2
# - Exposure (Cmax, AUC)
# - Ctrough
# - k(off)
# - avidity
# - Kₜ
# - binding constants
# - binding affinity
# - % inhibition
# - k(on)
# - K₇D
# - SI
# - equilibrium dissociation constant
# - IC90
# - IC99
# - Ka
# - pIC
# - K_a
# - appKi
# - alpha Ki
# - quenching constant
# - K₁
# - Emax
# - Inhibition (%)
# - Metric 1
# - Metric 2
# - Metric 3
# - Metric 4
# - Metric 5
# - Metric 6
# - Metric 7
# - Metric1
# - Metric2
# - Metric3
# - Metric4
# - Metric5
# - Metric6
# - Metric7
# - Metric8
# - k_a
# - k_d
# - logKi
# - F
# - SC50
# - Km
# - LD50/ED50
# - TC50/EC50
# - MIC100
# - affinity constant
# - AC1.4
# - pCa50
# - ID50
# - K_d
# - Vmax
# - Inhibition ratio
# - kdt½
# - t½
# - K<sub>M</sub>
# - Vy2
# - relaxivity
# - K*
# - K<sub>i</sub>
# - IQ
# - PLS(H/M)T1/2
# - pKB
# - LogEC50
# - affinities
# - AUC(0-t)
# - kon
# - EC₅₀
# - ID₅₀
# - Kₑ
# - EC75
# - MAD
# - EC80
# - IC10
# - ECso
# - Kr
# - K<sub>D</sub>
# - IC₅₀
# - IC₉₀
# - K<sub>a</sub>
# - uptake
# - half-life
# - ka
# - KA
# - IC50 ratio
# - kdis
# - K1
# - selectivity ratio
# - Sero-positivity rate
# - Sero-conversion rate
# - GMTs
# - K^
# - K,
# - EC90
# - EC
# - dimer/monomer equilibrium constant
# - EC50_MP
# - EC50_Mp
# - EC50i_ss
# - EC50i_peak
# - EC50_Ipeak
# - RKi
# - K(i)
# - Kdis
# - ProteinActivity
# - IC50, Ki
# - I
# - Kiapp
# - CCID50
# - Avidity for Binding to aggregated β-amyloid
# - k_on
# - k_off
# - Affinity
# - IC50/Ki
# - association rate
# - dissociation rate
# - EC70
# - association rate constant
# - dissociation rate constant
# - on-rate
# - off-rate
# - RA
# - IC50 or EC50
# - IC50 or Kd
# - RF
# - ARF
# - IC⁵⁹
# - Dissociation constant
# - 50% HA titer
# - GI50
# - Gl
# - LE
# - LLE
# - pKd
# - hKd/cKd
# - KD(M)
# - kd(1/s)
# - ka(1/Ms)
# - EC50 rel
# - Max. OD
# - t 1/2
# - IC95
# - K<sub>f</sub>
# - Kenhancer
# - Tm
# - GMIC50
# - ED_50
# - IC_50
# - K� seven D
# - sMIC
# - k_obs
# - k_inact
# - % ID/g
# - dyedK
# - MIC 50
# - MIC 90
# - Unknown
# - Dose
# - ΔG°
